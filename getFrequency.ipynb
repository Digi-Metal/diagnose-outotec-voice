# %%
# Read in a WAV and find the freq's
import pyaudio
import wave
import numpy as np

chunk = 2048

# open up a wave
wf = wave.open('sounds/device1_channel1_20181025150420.wav', 'rb')
swidth = wf.getsampwidth()
RATE = wf.getframerate()
# use a Blackman window
window = np.blackman(chunk)
# open stream
p = pyaudio.PyAudio()
stream = p.open(format =
                p.get_format_from_width(wf.getsampwidth()),
                channels = wf.getnchannels(),
                rate = RATE,
                output = True)

# read some data
data = wf.readframes(chunk)

# play stream and find the frequency of each chunk
while len(data) == chunk*swidth:
    # write data out to the audio stream
    stream.write(data)
    # unpack the data and times by the hamming window
    indata = np.array(wave.struct.unpack("%dh"%(len(data)/swidth),\
                                         data))*window
    # Take the fft and square each value
    fftData=abs(np.fft.rfft(indata))**2
    # find the maximum
    which = fftData[1:].argmax() + 1
    # use quadratic interpolation around the max
    if which != len(fftData)-1:
        y0,y1,y2 = np.log(fftData[which-1:which+2:])
        x1 = (y2 - y0) * .5 / (2 * y1 - y2 - y0)
        # find the frequency and output it
        thefreq = (which+x1)*RATE/chunk
        print ("The freq is %f Hz." % (thefreq))
    else:
        thefreq = which*RATE/chunk
        print ("The freq is %f Hz." % (thefreq))
    # read some more data
    data = wf.readframes(chunk)
if data:
    stream.write(data)
stream.close()
p.terminate()
# Out:
# The freq is 18761.432660 Hz.
# The freq is 135.704114 Hz.
# The freq is 56.113112 Hz.
# The freq is 48.981690 Hz.
# The freq is 22.213934 Hz.
# The freq is 33.127881 Hz.
# The freq is 214.241382 Hz.
# The freq is 38.250279 Hz.
# The freq is 54.491839 Hz.
# The freq is 44.010239 Hz.
# The freq is 278.007486 Hz.
# The freq is 48.068796 Hz.
# The freq is 50.551070 Hz.
# The freq is 52.732588 Hz.
# The freq is 88.486457 Hz.
# The freq is 46.318466 Hz.
# The freq is 117.354843 Hz.
# The freq is 36.152596 Hz.
# The freq is 40.885965 Hz.
# The freq is 35.408752 Hz.
# The freq is 64.770308 Hz.
# The freq is 19.463816 Hz.
# The freq is 25.161494 Hz.
# The freq is 29.456683 Hz.
# The freq is 31.755582 Hz.
# The freq is 18.216559 Hz.
# The freq is 34.932071 Hz.
# The freq is 10.193490 Hz.
# The freq is 33.210146 Hz.
# The freq is 25.563842 Hz.
# The freq is 33.058316 Hz.
# The freq is 37.976974 Hz.
# The freq is 41.305661 Hz.
# The freq is 25.962540 Hz.
# The freq is 189.193596 Hz.
# The freq is 49.067194 Hz.
# The freq is 26.017777 Hz.
# The freq is 40.822237 Hz.
# The freq is 107.725126 Hz.
# The freq is 472.917129 Hz.
# The freq is 56.499368 Hz.
# The freq is 137.563198 Hz.
# The freq is 428.321550 Hz.
# The freq is 37.237204 Hz.
# The freq is 490.697368 Hz.
# The freq is 35.328202 Hz.
# The freq is 202.408096 Hz.
# The freq is 38.257894 Hz.
# The freq is 7.956612 Hz.
# The freq is 54.971950 Hz.
# The freq is 33.995750 Hz.
# The freq is 35.236700 Hz.
# The freq is 139.958300 Hz.
# The freq is 40.947067 Hz.
# The freq is 35.384628 Hz.
# The freq is 14.668354 Hz.
# The freq is 36.336041 Hz.
# The freq is 45.880527 Hz.
# The freq is 50.558543 Hz.
# The freq is 37.544556 Hz.
# The freq is 69.297114 Hz.
# The freq is 49.466107 Hz.
# The freq is 199.769230 Hz.
# The freq is 118.096872 Hz.
# The freq is 60.712874 Hz.
# The freq is 84.108853 Hz.
# The freq is 54.861925 Hz.
# The freq is 29.715258 Hz.
# The freq is 151.491133 Hz.
# The freq is 181.319927 Hz.
# The freq is 64.188268 Hz.
# The freq is 47.669426 Hz.
# The freq is 149.193754 Hz.
# The freq is 43.642172 Hz.
# The freq is 113.626629 Hz.
# The freq is 93.581899 Hz.
# The freq is 41.851702 Hz.
# The freq is 60.733167 Hz.
# The freq is 35.424753 Hz.
# The freq is 134.841323 Hz.
# The freq is 158.871875 Hz.
# The freq is 110.097925 Hz.
# The freq is 25.093873 Hz.
# The freq is 38.233097 Hz.
# The freq is 42.763691 Hz.
# The freq is 44.361872 Hz.
# The freq is 50.795098 Hz.
# The freq is 36.834826 Hz.
# The freq is 57.729277 Hz.
# The freq is 47.166638 Hz.
# The freq is 44.433802 Hz.
# The freq is 25.576212 Hz.
# The freq is 46.717255 Hz.
# The freq is 24.163234 Hz.
# The freq is 33.610568 Hz.
# The freq is 38.401688 Hz.
# The freq is 38.218127 Hz.
# The freq is 80.616909 Hz.
# The freq is 65.395063 Hz.
# The freq is 104.177366 Hz.
# The freq is 34.334796 Hz.
# The freq is 27.984204 Hz.
# The freq is 40.741197 Hz.
# The freq is 20.169618 Hz.
# The freq is 215.773559 Hz.
# The freq is 210.766912 Hz.
# The freq is 27.924703 Hz.
# The freq is 49.743104 Hz.
# The freq is 46.113479 Hz.
# The freq is 101.594976 Hz.
# The freq is 29.913004 Hz.
# The freq is 192.588133 Hz.
# The freq is 53.766643 Hz.
# The freq is 32.188377 Hz.
# The freq is 52.758029 Hz.
# The freq is 60.242698 Hz.
# The freq is 17.965654 Hz.
# The freq is 41.790910 Hz.
# The freq is 115.542490 Hz.
# The freq is 177.347954 Hz.
# The freq is 44.048744 Hz.
# The freq is 195.879825 Hz.
# The freq is 39.899579 Hz.
# The freq is 153.349404 Hz.
# The freq is 51.318934 Hz.
# The freq is 62.479247 Hz.
# The freq is 36.273094 Hz.
# The freq is 60.070690 Hz.
# The freq is 52.504835 Hz.
# The freq is 44.474447 Hz.
# The freq is 30.525269 Hz.
# The freq is 33.739839 Hz.
# The freq is 37.340489 Hz.
# The freq is 44.391173 Hz.
# The freq is 46.165479 Hz.
# The freq is 188.117141 Hz.
# The freq is 45.341906 Hz.
# The freq is 170.511043 Hz.
# The freq is 33.467023 Hz.
# The freq is 38.789718 Hz.
# The freq is -1.783347 Hz.
# The freq is 60.268794 Hz.
# The freq is 26.294026 Hz.
# The freq is 43.446242 Hz.
# The freq is 26.697020 Hz.
# The freq is 253.643165 Hz.
# The freq is 51.164700 Hz.
# The freq is 421.411684 Hz.
# The freq is 190.516823 Hz.
# The freq is 201.623565 Hz.
# The freq is 199.290574 Hz.
# The freq is 56.744604 Hz.
# The freq is 220.801409 Hz.
# The freq is 75.338098 Hz.
# The freq is 45.703252 Hz.
# The freq is -39.930457 Hz.
# The freq is 46.061627 Hz.
# The freq is 239.765572 Hz.
# The freq is 129.842556 Hz.
# The freq is 46.622867 Hz.
# The freq is 43.142156 Hz.
# The freq is 52.347423 Hz.
# The freq is 33.285053 Hz.
# The freq is 240.591126 Hz.
# The freq is 58.447061 Hz.
# The freq is 168.875443 Hz.
# The freq is 54.419417 Hz.
# The freq is 287.062308 Hz.
# The freq is 140.092252 Hz.
# The freq is 48.070737 Hz.
# The freq is 45.334989 Hz.
# The freq is 39.091553 Hz.
# The freq is 36.416171 Hz.
# The freq is 186.550876 Hz.
# The freq is 179.727613 Hz.
# The freq is 36.312310 Hz.
# The freq is 48.709393 Hz.
# The freq is 190.132791 Hz.
# The freq is 37.383753 Hz.
# The freq is 7.267004 Hz.
# The freq is 15.882133 Hz.
# The freq is 55.250650 Hz.
# The freq is 39.595127 Hz.
# The freq is 19.319300 Hz.
# The freq is 11.153174 Hz.
# The freq is 37.739709 Hz.
# The freq is 19.035030 Hz.
# The freq is 33.755707 Hz.
# The freq is 52.428354 Hz.
# The freq is 43.674470 Hz.
# The freq is 193.340523 Hz.
# The freq is 89.800581 Hz.
# The freq is 69.313299 Hz.
# The freq is 198.998098 Hz.
# The freq is 41.508742 Hz.
# The freq is 52.888491 Hz.
# The freq is 44.417615 Hz.
# The freq is 42.980541 Hz.
# The freq is 9.946748 Hz.
# The freq is 56.751563 Hz.
# The freq is 31.710812 Hz.
# The freq is 46.459980 Hz.
# The freq is 63.583960 Hz.
# The freq is 41.193114 Hz.
# The freq is 413.660128 Hz.
# The freq is 38.473535 Hz.
# The freq is 172.621904 Hz.
# The freq is 37.472096 Hz.
# The freq is 27.864493 Hz.
# The freq is 40.136599 Hz.
# The freq is 297.603521 Hz.
# The freq is 43.666653 Hz.
# The freq is 43.221055 Hz.
# The freq is 50.933496 Hz.
# The freq is 167.366577 Hz.
# The freq is 38.298429 Hz.
# The freq is 49.204073 Hz.
# The freq is 38.175150 Hz.
# The freq is 39.072611 Hz.
# The freq is 41.966959 Hz.
# The freq is 48.760371 Hz.
# The freq is 51.505517 Hz.
# The freq is 47.040937 Hz.
# The freq is 43.357935 Hz.
# The freq is 38.187955 Hz.
# The freq is 43.855598 Hz.
# The freq is 48.927051 Hz.
# The freq is 284.746049 Hz.
# The freq is 56.739779 Hz.
# The freq is 75.868409 Hz.
# The freq is 52.119894 Hz.
# The freq is 33.685111 Hz.
# The freq is 185.105842 Hz.
# The freq is 56.033038 Hz.
# The freq is 53.881725 Hz.
# The freq is 1.942166 Hz.
# The freq is 53.353815 Hz.
# The freq is 197.255100 Hz.
# The freq is 48.386733 Hz.
# The freq is 40.875651 Hz.
# The freq is 31.586970 Hz.
# The freq is -9.210859 Hz.
# The freq is 88.865287 Hz.
# The freq is 40.542343 Hz.
# The freq is 37.690960 Hz.
# The freq is 36.344958 Hz.
# The freq is 165.207062 Hz.
# The freq is 14.865247 Hz.
# The freq is 130.742139 Hz.
# The freq is 14.935219 Hz.
# The freq is 33.997405 Hz.
# The freq is 196.793568 Hz.
# The freq is 186.637919 Hz.
# The freq is 33.824447 Hz.
# The freq is 34.024561 Hz.
# The freq is 40.553401 Hz.
# The freq is 48.183715 Hz.
# The freq is 26.915635 Hz.
# The freq is 142.145096 Hz.
# The freq is 46.362928 Hz.
# The freq is 42.734072 Hz.
# The freq is 191.312915 Hz.
# The freq is 38.016370 Hz.
# The freq is 94.178000 Hz.
# The freq is 64.618286 Hz.
# The freq is 43.335971 Hz.
# The freq is 58.642593 Hz.
# The freq is 191.103918 Hz.
# The freq is 185.969311 Hz.
# The freq is 187.320446 Hz.
# The freq is 85.708449 Hz.
# The freq is 43.853220 Hz.
# The freq is 192.087218 Hz.
# The freq is 19.448361 Hz.
# The freq is 161.853429 Hz.
# The freq is 139.967978 Hz.
# The freq is 46.979865 Hz.
# The freq is 199.123929 Hz.
# The freq is 39.120149 Hz.
# The freq is 34.750461 Hz.
# The freq is 41.630886 Hz.
# The freq is 27.504714 Hz.
# The freq is 52.553554 Hz.
# The freq is 37.500876 Hz.
# The freq is 64.182891 Hz.
# The freq is 49.426986 Hz.
# The freq is 45.548279 Hz.
# The freq is 134.799249 Hz.
# The freq is 1.728932 Hz.
# The freq is 44.347911 Hz.
# The freq is 32.508843 Hz.
# The freq is 32.251713 Hz.
# The freq is 62.669398 Hz.
# The freq is 60.648193 Hz.
# The freq is 46.173107 Hz.
# The freq is 32.180220 Hz.
# The freq is 35.189145 Hz.
# The freq is 33.780463 Hz.
# The freq is 94.525835 Hz.
# The freq is 51.217691 Hz.
# The freq is 51.128846 Hz.
# The freq is 41.177718 Hz.
# The freq is 45.738010 Hz.
# The freq is 504.994829 Hz.
# The freq is 73.522383 Hz.
# The freq is 67.754344 Hz.
# The freq is 534.357863 Hz.
# The freq is 52.240525 Hz.
# The freq is 45.194561 Hz.
# The freq is 63.109218 Hz.
# The freq is 46.435209 Hz.
# The freq is 84.162987 Hz.
# The freq is 74.225599 Hz.
# The freq is 176.634027 Hz.
# The freq is 117.061394 Hz.
# The freq is 46.366116 Hz.
# The freq is 55.765611 Hz.
# The freq is 47.266571 Hz.
# The freq is 33.853237 Hz.
# The freq is 43.779330 Hz.
# The freq is 37.504184 Hz.
# The freq is 46.664762 Hz.
# The freq is 277.807149 Hz.
# The freq is 57.534029 Hz.
# The freq is 20.362441 Hz.
# The freq is 52.227259 Hz.
# The freq is 32.620060 Hz.
# The freq is 25.968192 Hz.
# The freq is 49.756682 Hz.
# The freq is 32.868650 Hz.
# The freq is 272.098555 Hz.
# The freq is 93.471685 Hz.
# The freq is 42.183271 Hz.
# The freq is 69.949617 Hz.
# The freq is 20.575447 Hz.
# The freq is 66.102071 Hz.
# The freq is 24.452843 Hz.
# The freq is 31.290364 Hz.
# The freq is 27.375481 Hz.
# The freq is 41.548702 Hz.
# The freq is 38.955938 Hz.
# The freq is 57.040634 Hz.
# The freq is 60.002263 Hz.
# The freq is 47.918216 Hz.
# The freq is 145.135850 Hz.
# The freq is 60.469691 Hz.
# The freq is 21.561270 Hz.
# The freq is 63.504905 Hz.
# The freq is 49.348596 Hz.
# The freq is 85.818472 Hz.
# The freq is 40.840732 Hz.
# The freq is 31.960733 Hz.
# The freq is 237.705922 Hz.
# The freq is 54.395801 Hz.
# The freq is 172.987634 Hz.
# The freq is 35.822497 Hz.
# The freq is 49.846203 Hz.
# The freq is 96.276309 Hz.
# The freq is 40.479342 Hz.
# The freq is 560.125106 Hz.
# The freq is 58.270480 Hz.
# The freq is 62.895493 Hz.
# The freq is 31.792380 Hz.
# The freq is 140.737337 Hz.
# The freq is 31.711532 Hz.
# The freq is 33.744978 Hz.
# The freq is 34.944226 Hz.
# The freq is 38.233630 Hz.
# The freq is 45.098324 Hz.
# The freq is 30.994027 Hz.
# The freq is 29.808373 Hz.
# The freq is 33.398186 Hz.
# The freq is 27.136258 Hz.
# The freq is 55.647453 Hz.
# The freq is 36.564302 Hz.
# The freq is 86.831093 Hz.
# The freq is 37.172015 Hz.
# The freq is 280.078078 Hz.
# The freq is 25.799524 Hz.
# The freq is 6.838794 Hz.
# The freq is 64.473289 Hz.
# The freq is 51.094341 Hz.
# The freq is 184.835924 Hz.
# The freq is 233.677286 Hz.
# The freq is 54.176601 Hz.
# The freq is 22.320654 Hz.
# The freq is 52.184713 Hz.
# The freq is 30.719867 Hz.
# The freq is 235.456784 Hz.
# The freq is 39.527895 Hz.
# The freq is 47.793943 Hz.
# The freq is 54.149808 Hz.
# The freq is 40.395993 Hz.
# The freq is 73.547989 Hz.
# The freq is 194.607617 Hz.
# The freq is 49.367126 Hz.
# The freq is 418.684220 Hz.
# The freq is 41.799874 Hz.
# The freq is 136.815266 Hz.
# The freq is 210.360168 Hz.
# The freq is 44.969391 Hz.
# The freq is 173.388571 Hz.
# The freq is 45.189819 Hz.
# The freq is 14.705028 Hz.
# The freq is 6.937613 Hz.
# The freq is 65.828064 Hz.
# The freq is 35.531569 Hz.
# The freq is 168.782857 Hz.
# The freq is 206.978726 Hz.
# The freq is 1.932460 Hz.
# The freq is 36.898039 Hz.
# The freq is 56.718865 Hz.
# The freq is 58.111970 Hz.
# The freq is 41.353796 Hz.
# The freq is 32.780868 Hz.
# The freq is 48.434769 Hz.
# The freq is 158.127860 Hz.
# The freq is 50.677204 Hz.
# The freq is 43.450585 Hz.
# The freq is 77.254642 Hz.
# The freq is 414.535312 Hz.
# The freq is 74.245936 Hz.
# The freq is 282.246015 Hz.
# The freq is 48.479570 Hz.
# The freq is 48.034999 Hz.
# The freq is 45.775852 Hz.
# The freq is 19.606768 Hz.
# The freq is 37.635520 Hz.
# The freq is 14.047163 Hz.
# The freq is 71.256003 Hz.
# The freq is 54.511666 Hz.
# The freq is 153.130223 Hz.
# The freq is 37.514760 Hz.
# The freq is 68.305928 Hz.
# The freq is 48.494513 Hz.
# The freq is 120.659836 Hz.
# The freq is 41.078168 Hz.
# The freq is 40.099810 Hz.
# The freq is 30.435251 Hz.
# The freq is 32.211417 Hz.
# The freq is 40.688791 Hz.
# The freq is 22.702479 Hz.
# The freq is 41.810197 Hz.
# The freq is 47.203831 Hz.
# The freq is 36.728561 Hz.
# The freq is 29.462015 Hz.
# The freq is 33.707278 Hz.
# The freq is 41.294705 Hz.
# The freq is 32.258477 Hz.
# The freq is 32.640308 Hz.
# The freq is 28.964216 Hz.
# The freq is 30.940128 Hz.
# The freq is 105.712162 Hz.
# The freq is 53.009057 Hz.
# The freq is 34.568077 Hz.
# The freq is 28.363740 Hz.
# The freq is 41.984713 Hz.
# The freq is 19.267055 Hz.
# The freq is 36.746152 Hz.
# The freq is 37.747670 Hz.
# The freq is 54.393230 Hz.
# The freq is 32.540082 Hz.
# The freq is 32.338486 Hz.
# The freq is 25.359033 Hz.
# The freq is 30.817069 Hz.
# The freq is 32.475833 Hz.
# The freq is 57.389057 Hz.
# The freq is 68.958883 Hz.
# The freq is 38.987415 Hz.
# The freq is 51.052859 Hz.
# The freq is 23.712599 Hz.
# The freq is 43.095707 Hz.
# The freq is 49.545773 Hz.
# The freq is 105.895568 Hz.
# The freq is 40.342082 Hz.
# The freq is 63.268268 Hz.
# The freq is 22.308553 Hz.
# The freq is 36.360602 Hz.
# The freq is 199.341448 Hz.
# The freq is 11.776386 Hz.
# The freq is 51.769705 Hz.
# The freq is 12.893863 Hz.
# The freq is 42.839240 Hz.
# The freq is 33.404136 Hz.
# The freq is 47.486218 Hz.
# The freq is 40.292528 Hz.
# The freq is 37.255574 Hz.
# The freq is 99.107721 Hz.
# The freq is 33.777253 Hz.
# The freq is 69.033618 Hz.
# The freq is 38.336244 Hz.
# The freq is 46.592227 Hz.
# The freq is 63.602023 Hz.
# The freq is 29.681551 Hz.
# The freq is 44.339568 Hz.
# The freq is 49.314133 Hz.
# The freq is 68.821198 Hz.
# The freq is 54.674758 Hz.
# The freq is 471.390915 Hz.
# The freq is 48.081837 Hz.
# The freq is 44.975271 Hz.
# The freq is 243.703338 Hz.
# The freq is 49.018052 Hz.
# The freq is 42.049482 Hz.
# The freq is 26.501433 Hz.
# The freq is 294.030499 Hz.
# The freq is 30.378528 Hz.
# The freq is 41.307439 Hz.
# The freq is 33.698384 Hz.
# The freq is 114.135744 Hz.
# The freq is 35.123513 Hz.
# The freq is 38.456305 Hz.
# The freq is 88.680012 Hz.
# The freq is 419.863193 Hz.
# The freq is 56.658704 Hz.
# The freq is 125.041916 Hz.
# The freq is 29.779384 Hz.
# The freq is 46.932536 Hz.
# The freq is 64.171663 Hz.
# The freq is 52.079896 Hz.
# The freq is 73.673850 Hz.
# The freq is 36.116263 Hz.
# The freq is 40.125993 Hz.
# The freq is 43.452039 Hz.
# The freq is 35.824249 Hz.
# The freq is 20.528291 Hz.
# The freq is 36.718477 Hz.
# The freq is 245.224121 Hz.
# The freq is 148.863075 Hz.
# The freq is 36.014037 Hz.
# The freq is 68.787928 Hz.
# The freq is 50.725212 Hz.
# The freq is 201.100061 Hz.
# The freq is 53.917035 Hz.
# The freq is 69.517267 Hz.
# The freq is 44.582712 Hz.
# The freq is 150.615340 Hz.
# The freq is 108.533345 Hz.
# The freq is 41.077642 Hz.
# The freq is 55.341149 Hz.
# The freq is 46.793206 Hz.
# The freq is 287.828153 Hz.
# The freq is 42.504725 Hz.
# The freq is 45.415305 Hz.
# The freq is 136.556046 Hz.
# The freq is 32.653614 Hz.
# The freq is 47.154880 Hz.
# The freq is 64.655848 Hz.
# The freq is 31.176252 Hz.
# The freq is 48.738543 Hz.
# The freq is 42.173349 Hz.
# The freq is 187.863778 Hz.
# The freq is 48.782808 Hz.
# The freq is 209.310235 Hz.
# The freq is 168.455065 Hz.
# The freq is 58.842591 Hz.
# The freq is 29.411707 Hz.
# The freq is 60.976045 Hz.
# The freq is 15.076749 Hz.
# The freq is 43.302819 Hz.
# The freq is 8.082052 Hz.
# The freq is 35.027868 Hz.
# The freq is 43.165993 Hz.
# The freq is 48.766271 Hz.
# The freq is 191.801631 Hz.
# The freq is 46.305674 Hz.
# The freq is 23.372882 Hz.
# The freq is 44.720778 Hz.
# The freq is 34.520148 Hz.
# The freq is 29.328792 Hz.
# The freq is 45.292332 Hz.
# The freq is 38.420943 Hz.
# The freq is 25.041118 Hz.
# The freq is 18.598734 Hz.
# The freq is 48.398778 Hz.
# The freq is 49.142429 Hz.
# The freq is 44.530942 Hz.
# The freq is 70.265225 Hz.
# The freq is 75.721537 Hz.
# The freq is 60.718993 Hz.
# The freq is 82.353117 Hz.
# The freq is 49.230760 Hz.
# The freq is 45.978560 Hz.
# The freq is 39.432900 Hz.
# The freq is 70.544785 Hz.
# The freq is 38.255094 Hz.
# The freq is 31.634855 Hz.
# The freq is 61.939657 Hz.
# The freq is 39.143346 Hz.
# The freq is 29.761940 Hz.
# The freq is 27.253445 Hz.
# The freq is 31.659373 Hz.
# The freq is 52.344030 Hz.
# The freq is 91.193368 Hz.
# The freq is 51.791543 Hz.
# The freq is 30.244380 Hz.
# The freq is 26.454955 Hz.
# The freq is 37.765120 Hz.
# The freq is 59.568414 Hz.
# The freq is 50.371715 Hz.
# The freq is 32.250136 Hz.
# The freq is 45.116184 Hz.
# The freq is 38.237768 Hz.
# The freq is 37.708657 Hz.
# The freq is 43.019386 Hz.
# The freq is 31.902337 Hz.
# The freq is 48.754576 Hz.
# The freq is 41.260939 Hz.
# The freq is 28.925153 Hz.
# The freq is 170.423805 Hz.
# The freq is 51.729610 Hz.
# The freq is 45.858157 Hz.
# The freq is 480.212436 Hz.
# The freq is 43.121126 Hz.
# The freq is 57.171373 Hz.
# The freq is 38.561061 Hz.
# The freq is 45.054279 Hz.
# The freq is 31.880415 Hz.
# The freq is 38.744010 Hz.
# The freq is 57.492024 Hz.
# The freq is 42.748428 Hz.
# The freq is 21.806732 Hz.
# The freq is 47.621792 Hz.
# The freq is 63.208965 Hz.
# The freq is 164.993200 Hz.
# The freq is 52.538366 Hz.
# The freq is 183.061316 Hz.
# The freq is 73.571131 Hz.
# The freq is 139.538396 Hz.
# The freq is 46.833389 Hz.
# The freq is 49.996141 Hz.
# The freq is 44.952014 Hz.
# The freq is 60.035262 Hz.
# The freq is 15.765487 Hz.
# The freq is 42.476988 Hz.
# The freq is 75.718494 Hz.
# The freq is 49.990127 Hz.
# The freq is 47.354355 Hz.
# The freq is 46.849766 Hz.
# The freq is 40.166901 Hz.
# The freq is 46.778761 Hz.
# The freq is 39.072172 Hz.
# The freq is 54.040663 Hz.
# The freq is 175.757561 Hz.
# The freq is 24.863170 Hz.
# The freq is 38.173598 Hz.
# The freq is 78.008995 Hz.
# The freq is 178.302315 Hz.
# The freq is 12.620017 Hz.
# The freq is 50.754197 Hz.
# The freq is 177.356688 Hz.
# The freq is 7.522786 Hz.
# The freq is 32.841790 Hz.
# The freq is 48.840650 Hz.
# The freq is -143.857916 Hz.
# The freq is 52.479147 Hz.
# The freq is 26.791691 Hz.
# The freq is 168.792066 Hz.
# The freq is 85.397513 Hz.
# The freq is 38.345462 Hz.
# The freq is 47.189364 Hz.
# The freq is 48.674129 Hz.
# The freq is 33.454010 Hz.
# The freq is 14.532302 Hz.
# The freq is 50.871045 Hz.
# The freq is 37.151721 Hz.
# The freq is 9.097239 Hz.
# The freq is 39.866147 Hz.
# The freq is 171.275388 Hz.
# The freq is 73.267537 Hz.
# The freq is 36.026715 Hz.
# The freq is 44.774396 Hz.
# The freq is 33.346580 Hz.
# The freq is 49.500341 Hz.
# The freq is 34.677941 Hz.
# The freq is 57.449853 Hz.
# The freq is 23.756307 Hz.
# The freq is 32.750382 Hz.
# The freq is 30.430469 Hz.
# The freq is 11.425191 Hz.
# The freq is 188.012325 Hz.
# The freq is 30.656383 Hz.
# The freq is 49.770218 Hz.
# The freq is 58.992008 Hz.
# The freq is 48.867055 Hz.
# The freq is 34.036161 Hz.
# The freq is 36.256457 Hz.
# The freq is 53.740831 Hz.
# The freq is 187.004715 Hz.
# The freq is 68.870576 Hz.
# The freq is 58.667208 Hz.
# The freq is 33.720645 Hz.
# The freq is 49.798098 Hz.
# The freq is 114.692712 Hz.
# The freq is 19.891082 Hz.
# The freq is 188.088052 Hz.
# The freq is 184.952045 Hz.
# The freq is 32.375680 Hz.
# The freq is 65.016109 Hz.
# The freq is 35.773878 Hz.
# The freq is 58.386219 Hz.
# The freq is 174.923151 Hz.
# The freq is 185.137150 Hz.
# The freq is 38.551650 Hz.
# The freq is 44.907831 Hz.
# The freq is 28.863455 Hz.
# The freq is 21.952225 Hz.
# The freq is 72.197374 Hz.
# The freq is 48.710522 Hz.
# The freq is 3.795446 Hz.
# The freq is 64.025972 Hz.
# The freq is 160.794565 Hz.
# The freq is 163.490818 Hz.
# The freq is 57.659031 Hz.
# The freq is 188.196378 Hz.
# The freq is 175.420467 Hz.
# The freq is 28.467081 Hz.
# The freq is 22.782579 Hz.
# The freq is 21.244309 Hz.
# The freq is 184.890900 Hz.
# The freq is 47.826823 Hz.
# The freq is 87.183136 Hz.
# The freq is 51.483951 Hz.
# The freq is 40.900245 Hz.
# The freq is 34.300211 Hz.
# The freq is 32.837220 Hz.
# The freq is 45.133289 Hz.
# The freq is 50.437669 Hz.
# The freq is 39.480298 Hz.
# The freq is 34.320800 Hz.
# The freq is 35.377829 Hz.
# The freq is 61.610986 Hz.
# The freq is 40.943170 Hz.
# The freq is 10.668230 Hz.
# The freq is 52.541140 Hz.
# The freq is 55.138102 Hz.
# The freq is 37.738886 Hz.
# The freq is 269.323877 Hz.
# The freq is 47.965052 Hz.
# The freq is 52.996673 Hz.
# The freq is 36.416757 Hz.
# The freq is 271.339373 Hz.
# The freq is 58.765354 Hz.
# The freq is 62.371463 Hz.
# The freq is 46.721560 Hz.
# The freq is 134.036322 Hz.
# The freq is 48.555755 Hz.
# The freq is 40.766006 Hz.
# The freq is 33.930484 Hz.
# The freq is 285.737915 Hz.
# The freq is 48.414176 Hz.
# The freq is 38.677348 Hz.
# The freq is 35.624247 Hz.
# The freq is 37.645572 Hz.
# The freq is 41.785566 Hz.
# The freq is 48.671218 Hz.
# The freq is 411.693652 Hz.
# The freq is 79.621946 Hz.
# The freq is 29.974039 Hz.
# The freq is 52.257349 Hz.
# The freq is 32.629271 Hz.
# The freq is -9.894795 Hz.
# The freq is 300.620543 Hz.
# The freq is 195.233126 Hz.
# The freq is 137.309878 Hz.
# The freq is 39.554777 Hz.
# The freq is 37.322401 Hz.
# The freq is 52.803120 Hz.
# The freq is 60.842557 Hz.
# The freq is 34.930700 Hz.
# The freq is 48.495142 Hz.
# The freq is 41.765215 Hz.
# The freq is 43.789901 Hz.
# The freq is 43.380224 Hz.
# The freq is 33.969567 Hz.
# The freq is 41.628728 Hz.
# The freq is 50.473612 Hz.
# The freq is 55.892652 Hz.
# The freq is 33.474477 Hz.
# The freq is 174.861801 Hz.
# The freq is 41.633634 Hz.
# The freq is 14.392432 Hz.
# The freq is 10.529318 Hz.
# The freq is 56.013252 Hz.
# The freq is 178.076157 Hz.
# The freq is 4.996471 Hz.
# The freq is 68.099567 Hz.
# The freq is 33.030374 Hz.
# The freq is 3.475096 Hz.
# The freq is 31.031936 Hz.
# The freq is 50.795342 Hz.
# The freq is 39.508962 Hz.
# The freq is 37.778856 Hz.
# The freq is 60.665913 Hz.
# The freq is 36.721953 Hz.
# The freq is 46.110138 Hz.
# The freq is 167.353621 Hz.
# The freq is 24.977601 Hz.
# The freq is 57.914350 Hz.
# The freq is 50.249978 Hz.
# The freq is 448.013082 Hz.
# The freq is 194.838217 Hz.
# The freq is 51.413188 Hz.
# The freq is 51.786417 Hz.
# The freq is 164.927961 Hz.
# The freq is 13.604422 Hz.
# The freq is 42.136099 Hz.
# The freq is 40.273494 Hz.
# The freq is 80.605153 Hz.
# The freq is 69.392640 Hz.
# The freq is 58.275633 Hz.
# The freq is 33.997077 Hz.
# The freq is 39.275972 Hz.
# The freq is 29.414964 Hz.
# The freq is 49.697075 Hz.
# The freq is 57.256465 Hz.
# The freq is 87.875984 Hz.
# The freq is 35.012045 Hz.
# The freq is 53.479403 Hz.
# The freq is 181.626952 Hz.
# The freq is 398.677131 Hz.
# The freq is 129.322872 Hz.
# The freq is 273.565381 Hz.
# The freq is 58.394160 Hz.
# The freq is 6.417571 Hz.
# The freq is 52.779665 Hz.
# The freq is 66.907278 Hz.
# The freq is 62.609944 Hz.
# The freq is 50.643966 Hz.
# The freq is 73.820838 Hz.
# The freq is 53.807396 Hz.
# The freq is 60.905201 Hz.
# The freq is 38.485742 Hz.
# The freq is 216.997423 Hz.
# The freq is 50.097519 Hz.
# The freq is 33.380881 Hz.
# The freq is 35.279251 Hz.
# The freq is 37.057344 Hz.
# The freq is 180.653974 Hz.
# The freq is 50.251595 Hz.
# The freq is 21.212644 Hz.
# The freq is 50.563848 Hz.
# The freq is 54.720771 Hz.
# The freq is 184.396237 Hz.
# The freq is 64.210981 Hz.
# The freq is 35.949504 Hz.
# The freq is 68.907732 Hz.
# The freq is 101.887263 Hz.
# The freq is 41.006187 Hz.
# The freq is 53.093860 Hz.
# The freq is 63.125740 Hz.
# The freq is 33.513377 Hz.
# The freq is 202.796371 Hz.
# The freq is 32.971301 Hz.
# The freq is 61.444802 Hz.
# The freq is 44.491431 Hz.
# The freq is 86.689729 Hz.
# The freq is 43.168235 Hz.
# The freq is 52.235456 Hz.
# The freq is 39.589565 Hz.
# The freq is 32.580223 Hz.
# The freq is 45.978752 Hz.
# The freq is 39.121432 Hz.
# The freq is 37.658637 Hz.
# The freq is 39.825443 Hz.
# The freq is 41.067564 Hz.
# The freq is 44.088298 Hz.
# The freq is 139.148883 Hz.
# The freq is 40.922176 Hz.
# The freq is 54.725161 Hz.
# The freq is 40.993815 Hz.
# The freq is 50.280342 Hz.
# The freq is 177.583287 Hz.
# The freq is 46.390978 Hz.
# The freq is 36.705711 Hz.
# The freq is 66.800856 Hz.
# The freq is 38.197501 Hz.
# The freq is 88.748857 Hz.
# The freq is 347.227897 Hz.
# The freq is 55.665645 Hz.
# The freq is 191.624342 Hz.
# The freq is 49.460791 Hz.
# The freq is 180.530907 Hz.
# The freq is 188.832194 Hz.
# The freq is 90.134296 Hz.
# The freq is 172.828493 Hz.
# The freq is 43.363986 Hz.
# The freq is 13.889927 Hz.
# The freq is 197.292842 Hz.
# The freq is 195.497699 Hz.
# The freq is 47.218990 Hz.
# The freq is 65.191818 Hz.
# The freq is 35.571196 Hz.
# The freq is 44.787809 Hz.
# The freq is 52.091675 Hz.
# The freq is 36.201701 Hz.
# The freq is 44.944954 Hz.
# The freq is 34.238282 Hz.
# The freq is 52.460904 Hz.
# The freq is 32.443812 Hz.
# The freq is 45.989369 Hz.
# The freq is 56.660098 Hz.
# The freq is 33.347535 Hz.
# The freq is 42.277121 Hz.
# The freq is 34.479584 Hz.
# The freq is 33.563820 Hz.
# The freq is 191.626292 Hz.
# The freq is 56.810520 Hz.
# The freq is 274.647098 Hz.
# The freq is 42.248022 Hz.
# The freq is 38.085519 Hz.
# The freq is 32.840010 Hz.
# The freq is 93.591846 Hz.
# The freq is 51.742835 Hz.
# The freq is 39.085970 Hz.
# The freq is 49.840080 Hz.
# The freq is 40.835826 Hz.
# The freq is 29.488097 Hz.
# The freq is 48.256995 Hz.
# The freq is 85.314761 Hz.
# The freq is 45.261373 Hz.
# The freq is 130.353359 Hz.
# The freq is 164.872318 Hz.
# The freq is 58.333183 Hz.
# The freq is 44.332497 Hz.
# The freq is 43.056826 Hz.
# The freq is 49.168430 Hz.
# The freq is 48.376560 Hz.
# The freq is 44.044257 Hz.
# The freq is 135.708687 Hz.
# The freq is 54.401639 Hz.
# The freq is 41.214521 Hz.
# The freq is 34.363237 Hz.
# The freq is 49.226477 Hz.
# The freq is 38.790548 Hz.
# The freq is 34.519677 Hz.
# The freq is 37.037411 Hz.
# The freq is 32.007327 Hz.
# The freq is 39.971263 Hz.
# The freq is 51.371820 Hz.
# The freq is 68.181315 Hz.
# The freq is 65.142334 Hz.
# The freq is 38.192888 Hz.
# The freq is 69.481696 Hz.
# The freq is 95.929680 Hz.
# The freq is 412.979345 Hz.
# The freq is 140.965359 Hz.
# The freq is 33.833554 Hz.
# The freq is 43.609095 Hz.
# The freq is 44.494636 Hz.
# The freq is 36.329334 Hz.
# The freq is 32.968474 Hz.
# The freq is 51.132401 Hz.
# The freq is 37.287634 Hz.
# The freq is 36.558964 Hz.
# The freq is 127.807733 Hz.
# The freq is 32.067521 Hz.
# The freq is 48.880582 Hz.
# The freq is 54.589289 Hz.
# The freq is 47.864098 Hz.
# The freq is 36.068495 Hz.
# The freq is 53.691783 Hz.
# The freq is 20.463724 Hz.
# The freq is 39.698638 Hz.
# The freq is 36.837124 Hz.
# The freq is 139.507087 Hz.
# The freq is 61.294046 Hz.
# The freq is 45.088491 Hz.
# The freq is 50.787602 Hz.
# The freq is 44.379053 Hz.
# The freq is 38.159416 Hz.
# The freq is 42.554755 Hz.
# The freq is 37.553989 Hz.
# The freq is 43.419543 Hz.
# The freq is 39.223921 Hz.
# The freq is 42.416428 Hz.
# The freq is 180.856624 Hz.
# The freq is 55.312301 Hz.
# The freq is 45.885380 Hz.
# The freq is 54.386529 Hz.
# The freq is 37.079621 Hz.
# The freq is 282.738634 Hz.
# The freq is 64.739152 Hz.
# The freq is 280.519619 Hz.
# The freq is 40.548451 Hz.
# The freq is 51.652650 Hz.
# The freq is 392.821910 Hz.
# The freq is 58.644317 Hz.
# The freq is 48.272099 Hz.
# The freq is 50.253981 Hz.
# The freq is 46.218891 Hz.
# The freq is 32.618792 Hz.
# The freq is 68.054736 Hz.
# The freq is 64.578943 Hz.
# The freq is 41.275789 Hz.
# The freq is 33.602081 Hz.
# The freq is 135.922190 Hz.
# The freq is 40.420719 Hz.
# The freq is 37.230196 Hz.
# The freq is 260.227810 Hz.
# The freq is 63.728431 Hz.
# The freq is 44.684745 Hz.
# The freq is 44.009213 Hz.
# The freq is 57.644474 Hz.
# The freq is 28.692954 Hz.
# The freq is 56.189925 Hz.
# The freq is 227.641626 Hz.
# The freq is 187.558544 Hz.
# The freq is 31.227262 Hz.
# The freq is 47.697881 Hz.
# The freq is 57.737098 Hz.
# The freq is 182.505708 Hz.
# The freq is 318.642236 Hz.
# The freq is 46.646595 Hz.
# The freq is 169.485323 Hz.
# The freq is 176.601584 Hz.
# The freq is 52.910172 Hz.
# The freq is 52.042734 Hz.
# The freq is 70.194680 Hz.
# The freq is 43.288387 Hz.
# The freq is 48.573475 Hz.
# The freq is 45.405838 Hz.
# The freq is 274.026571 Hz.
# The freq is 44.998343 Hz.
# The freq is 43.365126 Hz.
# The freq is 36.141631 Hz.
# The freq is 20.284229 Hz.
# The freq is 42.741059 Hz.
# The freq is 48.310516 Hz.
# The freq is 182.247229 Hz.
# The freq is 47.939972 Hz.
# The freq is 191.204731 Hz.
# The freq is 43.435905 Hz.
# The freq is 34.041272 Hz.
# The freq is 67.474479 Hz.
# The freq is 199.133821 Hz.
# The freq is 58.625674 Hz.
# The freq is 183.602914 Hz.
# The freq is 39.537256 Hz.
# The freq is 37.046210 Hz.
# The freq is 128.903475 Hz.
# The freq is 24.961711 Hz.
# The freq is 36.563914 Hz.
# The freq is 53.335699 Hz.
# The freq is 40.458681 Hz.
# The freq is 59.043300 Hz.
# The freq is 41.335228 Hz.
# The freq is 180.782021 Hz.
# The freq is 39.622781 Hz.
# The freq is 37.327666 Hz.
# The freq is 42.678362 Hz.
# The freq is 120.867262 Hz.
# The freq is 45.211499 Hz.
# The freq is 6.732760 Hz.
# The freq is 53.023334 Hz.
# The freq is 120.360384 Hz.
# The freq is 50.487074 Hz.
# The freq is 227.201500 Hz.
# The freq is 29.643463 Hz.
# The freq is 220.743043 Hz.
# The freq is 40.468030 Hz.
# The freq is 38.727290 Hz.
# The freq is 22.432527 Hz.
# The freq is 40.895771 Hz.
# The freq is 41.692180 Hz.
# The freq is 114.480031 Hz.
# The freq is 42.234060 Hz.
# The freq is 34.698759 Hz.
# The freq is 53.753610 Hz.
# The freq is 49.087112 Hz.
# The freq is 82.930576 Hz.
# The freq is 35.672804 Hz.
# The freq is 40.141183 Hz.
# The freq is 20.977166 Hz.
# The freq is 45.674734 Hz.
# The freq is 187.772442 Hz.
# The freq is 132.699841 Hz.
# The freq is 32.225922 Hz.
# The freq is 56.987801 Hz.
# The freq is 37.418900 Hz.
# The freq is 33.480989 Hz.
# The freq is 36.125436 Hz.
# The freq is 41.385962 Hz.
# The freq is 40.731930 Hz.
# The freq is 40.326252 Hz.
# The freq is 38.188109 Hz.
# The freq is 34.764371 Hz.
# The freq is 47.772852 Hz.
# The freq is 40.962972 Hz.
# The freq is 29.736259 Hz.
# The freq is 39.570483 Hz.
# The freq is 45.158496 Hz.
# The freq is 39.827602 Hz.
# The freq is 41.660733 Hz.
# The freq is 43.219992 Hz.
# The freq is 45.491360 Hz.
# The freq is 35.901157 Hz.
# The freq is 58.612863 Hz.
# The freq is 74.654415 Hz.
# The freq is 271.422169 Hz.
# The freq is 58.790641 Hz.
# The freq is 52.149355 Hz.
# The freq is 66.970837 Hz.
# The freq is 58.038773 Hz.
# The freq is 27.970048 Hz.
# The freq is 131.615357 Hz.
# The freq is 60.820648 Hz.
# The freq is 43.829126 Hz.
# The freq is 43.710020 Hz.
# The freq is 30.034416 Hz.
# The freq is 34.878331 Hz.
# The freq is 40.939472 Hz.
# The freq is 13.647649 Hz.
# The freq is 20.558744 Hz.
# The freq is 29.665832 Hz.
# The freq is 31.165664 Hz.
# The freq is 53.267872 Hz.
# The freq is 44.924903 Hz.
# The freq is 33.936097 Hz.
# The freq is 30.057955 Hz.
# The freq is 197.621597 Hz.
# The freq is 35.303629 Hz.
# The freq is 143.259622 Hz.
# The freq is 42.530300 Hz.
# The freq is 34.932080 Hz.
# The freq is 28.908476 Hz.
# The freq is 38.196600 Hz.
# The freq is 42.196010 Hz.
# The freq is 31.535796 Hz.
# The freq is 43.162715 Hz.
# The freq is 32.578457 Hz.
# The freq is 24.672928 Hz.
# The freq is 16.715629 Hz.
# The freq is 34.271263 Hz.
# The freq is 33.353862 Hz.
# The freq is 31.304364 Hz.
# The freq is 238.053726 Hz.
# The freq is 31.224019 Hz.
# The freq is 33.423572 Hz.
# The freq is 43.573912 Hz.
# The freq is 34.400968 Hz.
# The freq is 38.169267 Hz.
# The freq is 46.066399 Hz.
# The freq is 32.022707 Hz.
# The freq is 52.944035 Hz.
# The freq is 137.512591 Hz.
# The freq is 53.519970 Hz.
# The freq is 39.427819 Hz.
# The freq is 348.492529 Hz.
# The freq is 41.882451 Hz.
# The freq is 61.617076 Hz.
# The freq is 45.447191 Hz.
# The freq is 81.832658 Hz.
# The freq is 51.216834 Hz.
# The freq is 53.307881 Hz.
# The freq is 50.677787 Hz.
# The freq is 44.093219 Hz.
# The freq is 14.890756 Hz.
# The freq is 48.369800 Hz.
# The freq is 41.357245 Hz.
# The freq is 49.424199 Hz.
# The freq is 41.983067 Hz.
# The freq is 61.102274 Hz.
# The freq is 53.648570 Hz.
# The freq is 143.631783 Hz.
# The freq is 47.050812 Hz.
# The freq is 60.912448 Hz.
# The freq is 30.861244 Hz.
# The freq is 52.759204 Hz.
# The freq is 56.406637 Hz.
# The freq is 51.759957 Hz.
# The freq is 62.364675 Hz.
# The freq is 36.101189 Hz.
# The freq is 285.580160 Hz.
# The freq is 37.032699 Hz.
# The freq is 287.139741 Hz.
# The freq is 46.511544 Hz.
# The freq is 21.612848 Hz.
# The freq is 129.853650 Hz.
# The freq is 36.710701 Hz.
# The freq is 43.517909 Hz.
# The freq is 87.571890 Hz.
# The freq is 33.529183 Hz.
# The freq is 52.077468 Hz.
# The freq is 40.370936 Hz.
# The freq is 54.272016 Hz.
# The freq is 37.115389 Hz.
# The freq is 43.574046 Hz.
# The freq is 53.987252 Hz.
# The freq is 50.436536 Hz.
# The freq is 165.436717 Hz.
# The freq is 52.192011 Hz.
# The freq is 62.925080 Hz.
# The freq is 136.739557 Hz.
# The freq is 55.149510 Hz.
# The freq is 63.080533 Hz.
# The freq is 71.122009 Hz.
# The freq is 151.530672 Hz.
# The freq is 50.518487 Hz.
# The freq is 131.678767 Hz.
# The freq is 38.294769 Hz.
# The freq is 39.844037 Hz.
# The freq is 70.122627 Hz.
# The freq is 48.389756 Hz.
# The freq is 114.886356 Hz.
# The freq is 148.612946 Hz.
# The freq is 45.245612 Hz.
# The freq is 52.531836 Hz.
# The freq is 38.906384 Hz.
# The freq is 15.886778 Hz.
# The freq is 202.756070 Hz.
# The freq is 18.627934 Hz.
# The freq is 170.764959 Hz.
# The freq is 43.243161 Hz.
# The freq is 33.801072 Hz.
# The freq is 78.472404 Hz.
# The freq is 48.865549 Hz.
# The freq is 123.430717 Hz.
# The freq is 184.999163 Hz.
# The freq is 178.402047 Hz.
# The freq is 47.466873 Hz.
# The freq is 55.390160 Hz.
# The freq is 164.438448 Hz.
# The freq is 53.621033 Hz.
# The freq is 33.834983 Hz.
# The freq is 211.689056 Hz.
# The freq is 32.737124 Hz.
# The freq is 33.064381 Hz.
# The freq is 46.323080 Hz.
# The freq is 44.207360 Hz.
# The freq is 39.216830 Hz.
# The freq is 46.638038 Hz.
# The freq is 166.017509 Hz.
# The freq is 39.121246 Hz.
# The freq is 150.185419 Hz.
# The freq is 42.506385 Hz.
# The freq is 27.582111 Hz.
# The freq is 46.175738 Hz.
# The freq is 72.373120 Hz.
# The freq is 14.866341 Hz.
# The freq is 45.070270 Hz.
# The freq is 35.716547 Hz.
# The freq is 58.921324 Hz.
# The freq is 54.169277 Hz.
# The freq is 48.686428 Hz.
# The freq is 49.615548 Hz.
# The freq is 133.175889 Hz.
# The freq is 60.410209 Hz.
# The freq is 48.750359 Hz.
# The freq is 58.224740 Hz.
# The freq is 44.189530 Hz.
# The freq is 44.421767 Hz.
# The freq is 42.749878 Hz.
# The freq is 290.780191 Hz.
# The freq is 68.794242 Hz.
# The freq is 48.539716 Hz.
# The freq is 43.823075 Hz.
# The freq is 166.744631 Hz.
# The freq is 196.949602 Hz.
# The freq is 41.759355 Hz.
# The freq is 52.273477 Hz.
# The freq is 544.738816 Hz.
# The freq is 60.621905 Hz.
# The freq is 45.991859 Hz.
# The freq is 40.668136 Hz.
# The freq is 63.391543 Hz.
# The freq is 44.953272 Hz.
# The freq is 289.281231 Hz.
# The freq is 44.007074 Hz.
# The freq is 187.325749 Hz.
# The freq is 41.147253 Hz.
# The freq is 27.498167 Hz.
# The freq is 54.580749 Hz.
# The freq is 277.551862 Hz.
# The freq is 33.946614 Hz.
# The freq is 45.416574 Hz.
# The freq is 55.945424 Hz.
# The freq is 296.974941 Hz.
# The freq is 41.101669 Hz.
# The freq is 32.935491 Hz.
# The freq is 50.225325 Hz.
# The freq is 48.523976 Hz.
# The freq is 34.553661 Hz.
# The freq is 417.222093 Hz.
# The freq is 48.221466 Hz.
# The freq is 33.438005 Hz.
# The freq is 53.938604 Hz.
# The freq is 101.164533 Hz.
# The freq is 35.937688 Hz.
# The freq is 42.659739 Hz.
# The freq is 46.610101 Hz.
# The freq is 39.601039 Hz.
# The freq is 41.508334 Hz.
# The freq is 42.464194 Hz.
# The freq is 32.937335 Hz.
# The freq is 36.935783 Hz.
# The freq is 43.809164 Hz.
# The freq is 9.959578 Hz.
# The freq is 50.265049 Hz.
# The freq is 42.592873 Hz.
# The freq is 13.793850 Hz.
# The freq is 29.122626 Hz.
# The freq is 32.979741 Hz.
# The freq is 25.176618 Hz.
# The freq is 21.664874 Hz.
# The freq is 37.441518 Hz.
# The freq is 55.621828 Hz.
# The freq is 50.204955 Hz.
# The freq is 33.204256 Hz.
# The freq is 422.771540 Hz.
# The freq is 44.164256 Hz.
# The freq is 209.848446 Hz.
# The freq is 53.877415 Hz.
# The freq is 46.642550 Hz.
# The freq is 34.654900 Hz.
# The freq is 61.972450 Hz.
# The freq is 39.201597 Hz.
# The freq is 225.894991 Hz.
# The freq is 49.571249 Hz.
# The freq is 88.950139 Hz.
# The freq is 20.327181 Hz.
# The freq is 112.174321 Hz.
# The freq is 6.529196 Hz.
# The freq is 8.052047 Hz.
# The freq is 175.661418 Hz.
# The freq is 66.732994 Hz.
# The freq is 66.179194 Hz.
# The freq is 137.663607 Hz.
# The freq is 42.462715 Hz.
# The freq is 270.083158 Hz.
# The freq is 26.247621 Hz.
# The freq is 48.968757 Hz.
# The freq is 83.355538 Hz.
# The freq is 45.637992 Hz.
# The freq is 74.288278 Hz.
# The freq is 39.697951 Hz.
# The freq is 49.387478 Hz.
# The freq is 125.716882 Hz.
# The freq is 82.111197 Hz.
# The freq is 42.048403 Hz.
# The freq is 47.009093 Hz.
# The freq is 48.162598 Hz.
# The freq is 55.746410 Hz.
# The freq is 39.329027 Hz.
# The freq is 46.610659 Hz.
# The freq is 79.808589 Hz.
# The freq is 49.936721 Hz.
# The freq is 55.652265 Hz.
# The freq is 413.343985 Hz.
# The freq is 38.625217 Hz.
# The freq is 38.828269 Hz.
# The freq is 54.809548 Hz.
# The freq is 21.033513 Hz.
# The freq is 36.475275 Hz.
# The freq is 37.493272 Hz.
# The freq is 39.892615 Hz.
# The freq is 30.597878 Hz.
# The freq is 52.485713 Hz.
# The freq is 62.256800 Hz.
# The freq is 74.615728 Hz.
# The freq is 34.215874 Hz.
# The freq is 49.156046 Hz.
# The freq is 40.244892 Hz.
# The freq is 34.277722 Hz.
# The freq is 36.801328 Hz.
# The freq is 39.184512 Hz.
# The freq is 78.804336 Hz.
# The freq is 37.708681 Hz.
# The freq is 59.116192 Hz.
# The freq is 54.681039 Hz.
# The freq is 49.993642 Hz.
# The freq is 31.238382 Hz.
# The freq is 37.672866 Hz.
# The freq is 229.924767 Hz.
# The freq is 44.212373 Hz.
# The freq is 43.164240 Hz.
# The freq is 57.569856 Hz.
# The freq is 29.253542 Hz.
# The freq is 34.437046 Hz.
# The freq is 45.964559 Hz.
# The freq is 209.370606 Hz.
# The freq is 25.939989 Hz.
# The freq is 54.548354 Hz.
# The freq is 45.740393 Hz.
# The freq is 44.907590 Hz.
# The freq is 66.283232 Hz.
# The freq is 49.367026 Hz.
# The freq is 33.882647 Hz.
# The freq is 44.586259 Hz.
# The freq is 37.402049 Hz.
# The freq is 60.822823 Hz.
# The freq is 39.968694 Hz.
# The freq is 410.313896 Hz.
# The freq is 75.248595 Hz.
# The freq is 45.122812 Hz.
# The freq is 51.182665 Hz.
# The freq is 43.563889 Hz.
# The freq is 205.099605 Hz.
# The freq is 409.081388 Hz.
# The freq is 166.643175 Hz.
# The freq is 38.879493 Hz.
# The freq is 36.896797 Hz.
# The freq is 123.254001 Hz.
# The freq is 49.775946 Hz.
# The freq is 35.335120 Hz.
# The freq is 57.037742 Hz.
# The freq is 48.991928 Hz.
# The freq is 43.955193 Hz.
# The freq is 125.856376 Hz.
# The freq is 20.913789 Hz.
# The freq is 32.947008 Hz.
# The freq is 45.747779 Hz.
# The freq is 44.168198 Hz.
# The freq is 42.267523 Hz.
# The freq is 49.361846 Hz.
# The freq is 36.711833 Hz.
# The freq is 42.502005 Hz.
# The freq is 42.308382 Hz.
# The freq is 58.685512 Hz.
# The freq is 42.464643 Hz.
# The freq is 33.357725 Hz.
# The freq is 45.384855 Hz.
# The freq is 38.190666 Hz.
# The freq is 23.394921 Hz.
# The freq is 48.289281 Hz.
# The freq is 55.208816 Hz.
# The freq is 44.988078 Hz.
# The freq is 45.440953 Hz.
# The freq is 16.940879 Hz.
# The freq is 36.813168 Hz.
# The freq is 408.919672 Hz.
# The freq is 46.906755 Hz.
# The freq is 562.229504 Hz.
# The freq is 31.813780 Hz.
# The freq is 28.883130 Hz.
# The freq is 27.478254 Hz.
# The freq is 31.566212 Hz.
# The freq is 49.291842 Hz.
# The freq is 35.223670 Hz.
# The freq is 96.921451 Hz.
# The freq is 37.299824 Hz.
# The freq is 32.504957 Hz.
# The freq is 27.151352 Hz.
# The freq is 41.830646 Hz.
# The freq is 40.639928 Hz.
# The freq is 40.940768 Hz.
# The freq is 287.436840 Hz.
# The freq is 43.865353 Hz.
# The freq is 35.916898 Hz.
# The freq is 48.600300 Hz.
# The freq is 54.571957 Hz.
# The freq is 52.264684 Hz.
# The freq is 48.132014 Hz.
# The freq is -68.130915 Hz.
# The freq is 15.025084 Hz.
# The freq is 40.457994 Hz.
# The freq is 46.403628 Hz.
# The freq is 50.501276 Hz.
# The freq is 24.693178 Hz.
# The freq is 44.497388 Hz.
# The freq is 53.056734 Hz.
# The freq is 44.349092 Hz.
# The freq is 75.147282 Hz.
# The freq is 86.411527 Hz.
# The freq is 48.927896 Hz.
# The freq is 180.492708 Hz.
# The freq is 42.301902 Hz.
# The freq is 53.696308 Hz.
# The freq is 45.503946 Hz.
# The freq is 67.926507 Hz.
# The freq is 43.498240 Hz.
# The freq is 35.344672 Hz.
# The freq is 180.818595 Hz.
# The freq is 45.886954 Hz.
# The freq is 84.595809 Hz.
# The freq is 45.561285 Hz.
# The freq is 39.928996 Hz.
# The freq is 47.150650 Hz.
# The freq is 43.662378 Hz.
# The freq is 110.456911 Hz.
# The freq is 38.017683 Hz.
# The freq is 41.223803 Hz.
# The freq is 32.322928 Hz.
# The freq is 46.113686 Hz.
# The freq is 41.916620 Hz.
# The freq is 44.901796 Hz.
# The freq is 50.361430 Hz.
# The freq is 33.688463 Hz.
# The freq is 57.843664 Hz.
# The freq is 35.770885 Hz.
# The freq is 242.356760 Hz.
# The freq is 11.206121 Hz.
# The freq is 46.612787 Hz.
# The freq is 48.666170 Hz.
# The freq is 53.576839 Hz.
# The freq is 50.926843 Hz.
# The freq is 39.940426 Hz.
# The freq is 33.255660 Hz.
# The freq is 19.147137 Hz.
# The freq is 37.084981 Hz.
# The freq is 91.978588 Hz.
# The freq is 48.856843 Hz.
# The freq is 57.009683 Hz.
# The freq is 39.294802 Hz.
# The freq is 48.077597 Hz.
# The freq is 33.326702 Hz.
# The freq is 52.670401 Hz.
# The freq is 426.676766 Hz.
# The freq is 42.663580 Hz.
# The freq is 95.463636 Hz.
# The freq is 46.960567 Hz.
# The freq is 35.192233 Hz.
# The freq is 205.539275 Hz.
# The freq is 39.203340 Hz.
# The freq is 32.501487 Hz.
# The freq is 46.078793 Hz.
# The freq is 415.382115 Hz.
# The freq is 34.423755 Hz.
# The freq is 47.668383 Hz.
# The freq is 39.707154 Hz.
# The freq is 50.393556 Hz.
# The freq is 43.349503 Hz.
# The freq is 38.444632 Hz.
# The freq is 15.681712 Hz.
# The freq is 52.768295 Hz.
# The freq is 46.956931 Hz.
# The freq is 251.286295 Hz.
# The freq is 44.328123 Hz.
# The freq is 56.073023 Hz.
# The freq is 37.041062 Hz.
# The freq is 193.479278 Hz.
# The freq is 43.397198 Hz.
# The freq is 86.065027 Hz.
# The freq is 141.944911 Hz.
# The freq is 38.086769 Hz.
# The freq is 10.244753 Hz.
# The freq is 188.204540 Hz.
# The freq is 131.219363 Hz.
# The freq is 77.166199 Hz.
# The freq is 64.886900 Hz.
# The freq is 46.702062 Hz.
# The freq is 51.374993 Hz.
# The freq is 158.724026 Hz.
# The freq is 241.977854 Hz.
# The freq is 211.739431 Hz.
# The freq is 47.341322 Hz.
# The freq is 60.770877 Hz.
# The freq is 65.066743 Hz.
# The freq is 64.113862 Hz.
# The freq is 33.751972 Hz.
# The freq is 229.265397 Hz.
# The freq is 60.646739 Hz.
# The freq is 41.613658 Hz.
# The freq is 42.261477 Hz.
# The freq is 178.893477 Hz.
# The freq is 42.264923 Hz.
# The freq is 55.715790 Hz.
# The freq is 13.538360 Hz.
# The freq is 9.762250 Hz.
# The freq is 40.499130 Hz.
# The freq is 46.772343 Hz.
# The freq is 80.843149 Hz.
# The freq is 280.526749 Hz.
# The freq is 37.211498 Hz.
# The freq is 46.684908 Hz.
# The freq is 40.070923 Hz.
# The freq is 58.372367 Hz.
# The freq is 176.282027 Hz.
# The freq is 45.469983 Hz.
# The freq is 52.874763 Hz.
# The freq is 42.475272 Hz.
# The freq is 40.550452 Hz.
# The freq is 34.283573 Hz.
# The freq is 38.792896 Hz.
# The freq is 27.430708 Hz.
# The freq is 40.207721 Hz.
# The freq is 50.399214 Hz.
# The freq is 30.065245 Hz.
# The freq is 35.163380 Hz.
# The freq is 33.854098 Hz.
# The freq is 113.450322 Hz.
# The freq is 63.500692 Hz.
# The freq is 57.368855 Hz.
# The freq is 49.976001 Hz.
# The freq is 15.291571 Hz.
# The freq is 55.021293 Hz.
# The freq is 177.123227 Hz.
# The freq is 32.778154 Hz.
# The freq is 55.723439 Hz.
# The freq is 195.324536 Hz.
# The freq is 71.307288 Hz.
# The freq is 414.854476 Hz.
# The freq is 44.242692 Hz.
# The freq is 55.305286 Hz.
# The freq is 405.144469 Hz.
# The freq is 31.708304 Hz.
# The freq is 412.372409 Hz.
# The freq is 37.090004 Hz.
# The freq is 29.504705 Hz.
# The freq is 40.749014 Hz.
# The freq is 137.061833 Hz.
# The freq is 51.756573 Hz.
# The freq is 40.103626 Hz.
# The freq is 89.683014 Hz.
# The freq is 45.314135 Hz.
# The freq is 6.720111 Hz.
# The freq is 284.982201 Hz.
# The freq is 125.515288 Hz.
# The freq is 42.923922 Hz.
# The freq is 49.271198 Hz.
# The freq is 44.115932 Hz.
# The freq is 36.657496 Hz.
# The freq is 58.044511 Hz.
# The freq is 30.551075 Hz.
# The freq is 59.394719 Hz.
# The freq is 44.442308 Hz.
# The freq is 34.279944 Hz.
# The freq is 4.323592 Hz.
# The freq is 42.329146 Hz.
# The freq is 36.948800 Hz.
# The freq is 36.388479 Hz.
# The freq is 165.342067 Hz.
# The freq is 112.399960 Hz.
# The freq is 35.360717 Hz.
# The freq is 47.580388 Hz.
# The freq is 36.213662 Hz.
# The freq is 179.348820 Hz.
# The freq is 45.777951 Hz.
# The freq is 151.815018 Hz.
# The freq is 495.979536 Hz.
# The freq is 108.108585 Hz.
# The freq is 34.716549 Hz.
# The freq is 42.756638 Hz.
# The freq is 32.633761 Hz.
# The freq is 41.561923 Hz.
# The freq is 174.179680 Hz.
# The freq is 55.243237 Hz.
# The freq is 43.099387 Hz.
# The freq is 38.894002 Hz.
# The freq is 46.261995 Hz.
# The freq is 101.206151 Hz.
# The freq is 54.308215 Hz.
# The freq is 120.006840 Hz.
# The freq is 38.913051 Hz.
# The freq is 76.493437 Hz.
# The freq is 47.244733 Hz.
# The freq is 236.332387 Hz.
# The freq is 55.464635 Hz.
# The freq is 35.304961 Hz.
# The freq is 52.317091 Hz.
# The freq is 18.313425 Hz.
# The freq is 62.101655 Hz.
# The freq is 33.221749 Hz.
# The freq is 38.116990 Hz.
# The freq is 42.460050 Hz.
# The freq is 38.528614 Hz.
# The freq is 46.413342 Hz.
# The freq is 129.340309 Hz.
# The freq is 199.097645 Hz.
# The freq is 51.516902 Hz.
# The freq is 34.160120 Hz.
# The freq is 36.311088 Hz.
# The freq is 38.041585 Hz.
# The freq is 42.487315 Hz.
# The freq is 42.045470 Hz.
# The freq is 49.780215 Hz.
# The freq is 34.620468 Hz.
# The freq is 51.717270 Hz.
# The freq is 6.511440 Hz.
# The freq is 46.695007 Hz.
# The freq is 122.223862 Hz.
# The freq is 42.820248 Hz.
# The freq is 58.006383 Hz.
# The freq is 41.201583 Hz.
# The freq is 36.876954 Hz.
# The freq is 210.509417 Hz.
# The freq is 44.792253 Hz.
# The freq is 29.037293 Hz.
# The freq is 39.605164 Hz.
# The freq is 104.654408 Hz.
# The freq is 48.489901 Hz.
# The freq is 31.898503 Hz.
# The freq is 31.623388 Hz.
# The freq is 51.144647 Hz.
# The freq is 48.272660 Hz.
# The freq is 196.247515 Hz.
# The freq is 43.430688 Hz.
# The freq is 168.908819 Hz.
# The freq is 33.385664 Hz.
# The freq is 57.141747 Hz.
# The freq is 32.039335 Hz.
# The freq is 190.514563 Hz.
# The freq is 43.219855 Hz.
# The freq is 134.155286 Hz.
# The freq is 30.377711 Hz.
# The freq is 33.684301 Hz.
# The freq is 33.050316 Hz.
# The freq is 43.740455 Hz.
# The freq is 36.110303 Hz.
# The freq is 91.318825 Hz.
# The freq is 19.229067 Hz.
# The freq is 41.895075 Hz.
# The freq is 41.025344 Hz.
# The freq is 25.599524 Hz.
# The freq is 40.371957 Hz.
# The freq is 41.370819 Hz.
# The freq is 52.437015 Hz.
# The freq is 33.056457 Hz.
# The freq is 36.850755 Hz.
# The freq is 32.815948 Hz.
# The freq is 41.197457 Hz.
# The freq is 48.516203 Hz.
# The freq is 128.165201 Hz.
# The freq is 31.432790 Hz.
# The freq is 38.050541 Hz.
# The freq is 50.604887 Hz.
# The freq is 27.671772 Hz.
# The freq is 409.260893 Hz.
# The freq is 190.248925 Hz.
# The freq is 44.690195 Hz.
# The freq is 33.981718 Hz.
# The freq is 52.714305 Hz.
# The freq is 37.627404 Hz.
# The freq is 43.894512 Hz.
# The freq is 42.351005 Hz.
# The freq is 32.360030 Hz.
# The freq is 34.079525 Hz.
# The freq is 33.821981 Hz.
# The freq is 46.385679 Hz.
# The freq is 46.415759 Hz.
# The freq is 82.803626 Hz.
# The freq is 29.413552 Hz.
# The freq is 36.735149 Hz.
# The freq is 35.287821 Hz.
# The freq is 44.689809 Hz.
# The freq is 30.302021 Hz.
# The freq is 36.786361 Hz.
# The freq is 38.289634 Hz.
# The freq is 29.116072 Hz.
# The freq is 30.032903 Hz.
# The freq is 37.051338 Hz.
# The freq is 37.174559 Hz.
# The freq is 19.716168 Hz.
# The freq is 23.577353 Hz.
# The freq is 83.748359 Hz.
# The freq is 48.656253 Hz.
# The freq is 37.139384 Hz.
# The freq is 63.504243 Hz.
# The freq is 43.332017 Hz.
# The freq is 24.059514 Hz.
# The freq is 44.679450 Hz.
# The freq is 42.445866 Hz.
# The freq is 49.494606 Hz.
# The freq is 42.782028 Hz.
# The freq is 47.715881 Hz.
# The freq is 42.194506 Hz.
# The freq is 80.509827 Hz.
# The freq is 48.927821 Hz.
# The freq is 140.231138 Hz.
# The freq is 2.862236 Hz.
# The freq is 34.246413 Hz.
# The freq is 50.185144 Hz.
# The freq is 31.994663 Hz.
# The freq is 48.125170 Hz.
# The freq is 42.287514 Hz.
# The freq is 71.881305 Hz.
# The freq is 129.887943 Hz.
# The freq is 40.407104 Hz.
# The freq is 47.329696 Hz.
# The freq is 49.965381 Hz.
# The freq is 55.620321 Hz.
# The freq is 45.595667 Hz.
# The freq is 46.706620 Hz.
# The freq is 64.364634 Hz.
# The freq is 37.618387 Hz.
# The freq is 31.263304 Hz.
# The freq is 51.236071 Hz.
# The freq is 55.010391 Hz.
# The freq is 38.797751 Hz.
# The freq is 40.843780 Hz.
# The freq is 41.892958 Hz.
# The freq is 27.421252 Hz.
# The freq is 45.229506 Hz.
# The freq is 60.728527 Hz.
# The freq is 50.259567 Hz.
# The freq is 44.373772 Hz.
# The freq is 55.774342 Hz.
# The freq is 132.789982 Hz.
# The freq is 195.753125 Hz.
# The freq is 47.882378 Hz.
# The freq is 57.225776 Hz.
# The freq is 103.287586 Hz.
# The freq is 40.149956 Hz.
# The freq is 37.435322 Hz.
# The freq is 9.771568 Hz.
# The freq is 42.967981 Hz.
# The freq is 41.087841 Hz.
# The freq is 49.409501 Hz.
# The freq is 46.931885 Hz.
# The freq is 30.965863 Hz.
# The freq is 35.970602 Hz.
# The freq is 45.029847 Hz.
# The freq is 37.250469 Hz.
# The freq is 13.163882 Hz.
# The freq is 38.096179 Hz.
# The freq is 23.945387 Hz.
# The freq is 36.084307 Hz.
# The freq is 37.595052 Hz.
# The freq is 39.039906 Hz.
# The freq is 47.899476 Hz.
# The freq is 321.733189 Hz.
# The freq is 51.208020 Hz.
# The freq is 39.363644 Hz.
# The freq is 36.020990 Hz.
# The freq is 44.464419 Hz.
# The freq is 82.674511 Hz.
# The freq is 45.661893 Hz.
# The freq is 46.176655 Hz.
# The freq is 44.063275 Hz.
# The freq is 44.866569 Hz.
# The freq is 30.314046 Hz.
# The freq is 49.525489 Hz.
# The freq is 53.339736 Hz.
# The freq is 177.870410 Hz.
# The freq is 53.044499 Hz.
# The freq is 33.524362 Hz.
# The freq is 40.845411 Hz.
# The freq is 46.386207 Hz.
# The freq is 13.614410 Hz.
# The freq is 43.796520 Hz.
# The freq is 35.122532 Hz.
# The freq is 39.593986 Hz.
# The freq is 52.911192 Hz.
# The freq is 87.643388 Hz.
# ...
# The freq is 35.085787 Hz.
# The freq is 42.598560 Hz.
# The freq is 18.563101 Hz.
# The freq is 36.437334 Hz.
# The freq is 1221.441682 Hz.
# The freq is 55.794502 Hz.
# The freq is 1221.619735 Hz.
# The freq is 35.814727 Hz.
# The freq is 49.150160 Hz.
# The freq is 2445.070499 Hz.
# The freq is 34.181578 Hz.
# The freq is 46.117686 Hz.
# The freq is 129.787411 Hz.
# The freq is 14.112455 Hz.
# The freq is 39.995979 Hz.
# The freq is 40.607890 Hz.
# The freq is 38.764527 Hz.
# The freq is 44.681255 Hz.
# The freq is 35.207709 Hz.
# The freq is 200.413638 Hz.
# The freq is 46.183084 Hz.
# The freq is 43.434501 Hz.
# The freq is 44.735286 Hz.
# The freq is 49.583178 Hz.
# The freq is 149.752315 Hz.
# The freq is 37.826532 Hz.
# The freq is 38.794347 Hz.
# The freq is 137.578730 Hz.
# The freq is 35.181013 Hz.
# The freq is 124.067569 Hz.
# The freq is 72.824908 Hz.
# The freq is 36.310246 Hz.
# The freq is 2443.915865 Hz.
# The freq is 2444.542050 Hz.
# The freq is 41.872442 Hz.
# The freq is 2441.752418 Hz.
# The freq is 35.876572 Hz.
# The freq is 2446.717740 Hz.
# The freq is 1221.220023 Hz.
# The freq is 1221.551714 Hz.
# The freq is 47.736089 Hz.
# The freq is 1220.601165 Hz.
# The freq is 1222.543812 Hz.
# The freq is 1222.799321 Hz.
# The freq is 1222.299676 Hz.
# The freq is 1220.301734 Hz.
# The freq is 1221.727449 Hz.
# The freq is 1221.878617 Hz.
# The freq is 1221.910629 Hz.
# The freq is 1221.783819 Hz.
# The freq is 1221.579384 Hz.
# The freq is 1222.069606 Hz.
# The freq is 1221.923333 Hz.
# The freq is 1221.722189 Hz.
# The freq is 1221.020371 Hz.
# The freq is 1221.356708 Hz.
# The freq is 1221.065349 Hz.
# The freq is 1221.087082 Hz.
# The freq is 1220.815253 Hz.
# The freq is 1220.545866 Hz.
# The freq is 1221.216261 Hz.
# The freq is 1220.958408 Hz.
# The freq is 1221.203995 Hz.
# The freq is 1220.957456 Hz.
# The freq is 1220.621885 Hz.
# The freq is 1220.855072 Hz.
# The freq is 1221.140272 Hz.
# The freq is 1220.759660 Hz.
# The freq is 1221.295838 Hz.
# The freq is 1220.021200 Hz.
# The freq is 1220.375457 Hz.
# The freq is 1219.885551 Hz.
# The freq is 1220.482285 Hz.
# The freq is 1220.332933 Hz.
# The freq is 1219.624110 Hz.
# The freq is 1220.535923 Hz.
# The freq is 1220.035874 Hz.
# The freq is 1220.609370 Hz.
# The freq is 1220.380081 Hz.
# The freq is 1220.562311 Hz.
# The freq is 1221.552311 Hz.
# The freq is 1220.649023 Hz.
# The freq is 1221.109157 Hz.
# The freq is 1220.613662 Hz.
# The freq is 1220.528780 Hz.
# The freq is 1220.345677 Hz.
# The freq is 1220.430399 Hz.
# The freq is 1221.617554 Hz.
# The freq is 1220.886573 Hz.
# The freq is 1220.700089 Hz.
# The freq is 1220.483825 Hz.
# The freq is 1221.048069 Hz.
# The freq is 1221.415758 Hz.
# The freq is 1221.628360 Hz.
# The freq is 1220.904738 Hz.
# The freq is 1222.107514 Hz.
# The freq is 1220.576686 Hz.
# The freq is 1221.465874 Hz.
# The freq is 1222.384165 Hz.
# The freq is 1221.388083 Hz.
# The freq is 1221.825217 Hz.
# The freq is 1221.663719 Hz.
# The freq is 1221.495277 Hz.
# The freq is 1221.144912 Hz.
# The freq is 1221.810146 Hz.
# The freq is 1221.679591 Hz.
# The freq is 1221.744195 Hz.
# The freq is 1220.911861 Hz.
# The freq is 1220.843446 Hz.
# The freq is 1221.146715 Hz.
# The freq is 1220.060904 Hz.
# The freq is 1220.223409 Hz.
# The freq is 1219.362716 Hz.
# The freq is 1219.868184 Hz.
# The freq is 1219.858621 Hz.
# The freq is 1219.567179 Hz.
# The freq is 1221.008612 Hz.
# The freq is 1219.481778 Hz.
# The freq is 1219.654830 Hz.
# The freq is 1220.156688 Hz.
# The freq is 1219.637797 Hz.
# The freq is 1220.116427 Hz.
# The freq is 1219.242409 Hz.
# The freq is 1219.268196 Hz.
# The freq is 1219.947346 Hz.
# The freq is 1220.575814 Hz.
# The freq is 1219.723642 Hz.
# The freq is 1219.686954 Hz.
# The freq is 1220.232589 Hz.
# The freq is 1220.393112 Hz.
# The freq is 1220.005073 Hz.
# The freq is 1220.628996 Hz.
# The freq is 1219.706721 Hz.
# The freq is 1221.160143 Hz.
# The freq is 1219.433970 Hz.
# The freq is 1220.553107 Hz.
# The freq is 1221.530799 Hz.
# The freq is 1220.504221 Hz.
# The freq is 1221.263670 Hz.
# The freq is 1221.295544 Hz.
# The freq is 1221.207621 Hz.
# The freq is 1220.952649 Hz.
# The freq is 2441.709140 Hz.
# The freq is 1220.246404 Hz.
# The freq is 2442.221203 Hz.
# The freq is 2441.065585 Hz.
# The freq is 2441.574524 Hz.
# The freq is 2441.414854 Hz.
# The freq is 2440.494294 Hz.
# The freq is 2440.631929 Hz.
# The freq is 2441.384864 Hz.
# The freq is 2440.988502 Hz.
# The freq is 2442.232737 Hz.
# The freq is 2439.802335 Hz.
# The freq is 1221.343335 Hz.
# The freq is 1221.182283 Hz.
# The freq is 1220.906128 Hz.
# The freq is 35.733728 Hz.
# The freq is 1220.369642 Hz.
# The freq is 40.533448 Hz.
# The freq is 1221.298527 Hz.
# The freq is 38.782622 Hz.
# The freq is 36.496938 Hz.
# The freq is 1219.394763 Hz.
# The freq is 1221.061828 Hz.
# The freq is 1220.726902 Hz.
# The freq is 42.931554 Hz.
# The freq is 1220.570900 Hz.
# The freq is 1221.065891 Hz.
# The freq is 42.753764 Hz.
# The freq is 1221.632069 Hz.
# The freq is 1220.003899 Hz.
# The freq is 50.374753 Hz.
# The freq is 1220.801477 Hz.
# The freq is 1220.797363 Hz.
# The freq is 1219.204932 Hz.
# The freq is 1218.405471 Hz.
# The freq is 1220.563303 Hz.
# The freq is 47.369963 Hz.
# The freq is 1220.146870 Hz.
# The freq is 1219.849014 Hz.
# The freq is 1221.015402 Hz.
# The freq is 1221.271123 Hz.
# The freq is 2441.224664 Hz.
# The freq is 2441.406299 Hz.
# The freq is 2441.703960 Hz.
# The freq is 2441.631642 Hz.
# The freq is 2441.711307 Hz.
# The freq is 2442.142057 Hz.
# The freq is 2442.007811 Hz.
# The freq is 2441.618797 Hz.
# The freq is 2442.082356 Hz.
# The freq is 2441.868614 Hz.
# The freq is 2441.368678 Hz.
# The freq is 2440.799100 Hz.
# The freq is 2441.512168 Hz.
# The freq is 2440.705697 Hz.
# The freq is 2441.783960 Hz.
# The freq is 2441.476058 Hz.
# The freq is 2441.034064 Hz.
# The freq is 2441.148495 Hz.
# The freq is 2441.555848 Hz.
# The freq is 2441.929693 Hz.
# The freq is 2442.279005 Hz.
# The freq is 2441.946388 Hz.
# The freq is 1221.967690 Hz.
# The freq is 1221.581291 Hz.
# The freq is 1222.339817 Hz.
# The freq is 1221.218843 Hz.
# The freq is 1220.758882 Hz.
# The freq is 1220.926640 Hz.
# The freq is 2442.331591 Hz.
# The freq is 1223.068547 Hz.
# The freq is 30.519416 Hz.
# The freq is 2440.701470 Hz.
# The freq is 2443.152159 Hz.
# The freq is 36.084925 Hz.
# The freq is 2441.322086 Hz.
# The freq is 2440.837786 Hz.
# The freq is 2440.256566 Hz.
# The freq is 2442.140010 Hz.
# The freq is 2443.067401 Hz.
# The freq is 1220.472837 Hz.
# The freq is 1220.188413 Hz.
# The freq is 1221.960373 Hz.
# The freq is 1220.850032 Hz.
# The freq is 1220.793191 Hz.
# The freq is 47.023103 Hz.
# The freq is 1220.512662 Hz.
# The freq is 1220.402090 Hz.
# The freq is 1220.585759 Hz.
# The freq is 1220.254407 Hz.
# The freq is 1220.248468 Hz.
# The freq is 1221.185088 Hz.
# The freq is 1221.839073 Hz.
# The freq is 2443.080600 Hz.
# The freq is 2443.210714 Hz.
# The freq is 2443.267930 Hz.
# The freq is 2442.939443 Hz.
# The freq is 2442.837539 Hz.
# The freq is 2442.748093 Hz.
# The freq is 2443.033741 Hz.
# The freq is 2442.620342 Hz.
# The freq is 2442.489957 Hz.
# The freq is 2442.802501 Hz.
# The freq is 2442.630166 Hz.
# The freq is 1222.072078 Hz.
# The freq is 1221.005494 Hz.
# The freq is 1221.350416 Hz.
# The freq is 1221.320761 Hz.
# The freq is 1221.268732 Hz.
# The freq is 1221.704047 Hz.
# The freq is 1221.581963 Hz.
# The freq is 1220.865323 Hz.
# The freq is 1222.116514 Hz.
# The freq is 1221.798111 Hz.
# The freq is 1221.818158 Hz.
# The freq is 1221.101578 Hz.
# The freq is 1221.923731 Hz.
# The freq is 1221.035698 Hz.
# The freq is 1221.184933 Hz.
# The freq is 1221.164984 Hz.
# The freq is 1221.023806 Hz.
# The freq is 1221.727883 Hz.
# The freq is 1221.267488 Hz.
# The freq is 1221.367221 Hz.
# The freq is 1221.327876 Hz.
# The freq is 1221.235221 Hz.
# The freq is 1220.258735 Hz.
# The freq is 1220.892784 Hz.
# The freq is 1220.533590 Hz.
# The freq is 1221.313053 Hz.
# The freq is 1221.233617 Hz.
# The freq is 1220.717670 Hz.
# The freq is 2442.021972 Hz.
# The freq is 2442.056087 Hz.
# The freq is 2440.910643 Hz.
# The freq is 2440.884756 Hz.
# The freq is 2440.812153 Hz.
# The freq is 2440.574743 Hz.
# The freq is 2440.565909 Hz.
# The freq is 2440.620245 Hz.
# The freq is 2440.552674 Hz.
# The freq is 2439.937299 Hz.
# The freq is 2440.022916 Hz.
# The freq is 2440.750692 Hz.
# The freq is 2439.705829 Hz.
# The freq is 2439.659304 Hz.
# The freq is 2439.338687 Hz.
# The freq is 2439.327636 Hz.
# The freq is 2439.312354 Hz.
# The freq is 2438.893888 Hz.
# The freq is 2438.693980 Hz.
# The freq is 2438.999011 Hz.
# The freq is 2439.238353 Hz.
# The freq is 2438.613428 Hz.
# The freq is 2438.780669 Hz.
# The freq is 2438.287133 Hz.
# The freq is 2438.449238 Hz.
# The freq is 2438.144605 Hz.
# The freq is 39.020297 Hz.
# The freq is 2439.759855 Hz.
# The freq is 41.947590 Hz.
# The freq is 2440.142123 Hz.
# The freq is 2439.778603 Hz.
# The freq is 139.035595 Hz.
# The freq is 45.898989 Hz.
# The freq is 67.161629 Hz.
# The freq is 2438.579986 Hz.
# The freq is 138.251377 Hz.
# The freq is 41.271217 Hz.
# The freq is 35.404845 Hz.
# The freq is 44.491963 Hz.
# The freq is 45.635731 Hz.
# The freq is 130.150465 Hz.
# The freq is 31.734513 Hz.
# The freq is 134.047517 Hz.
# The freq is 2437.593848 Hz.
# The freq is 2438.394640 Hz.
# The freq is 35.696085 Hz.
# The freq is 26.433647 Hz.
# The freq is 2439.225565 Hz.
# The freq is 43.189509 Hz.
# The freq is 1219.020956 Hz.
# The freq is 1219.877792 Hz.
# The freq is 45.873869 Hz.
# The freq is 1218.718330 Hz.
# The freq is 1219.296914 Hz.
# The freq is 1219.409060 Hz.
# The freq is 1219.115271 Hz.
# The freq is 1219.459711 Hz.
# The freq is 1219.662323 Hz.
# The freq is 1219.995705 Hz.
# The freq is 1219.594923 Hz.
# The freq is 1219.978120 Hz.
# The freq is 1219.258567 Hz.
# The freq is 1220.044960 Hz.
# The freq is 1219.249955 Hz.
# The freq is 1219.066128 Hz.
# The freq is 1218.231243 Hz.
# The freq is 1219.400180 Hz.
# The freq is 1219.397156 Hz.
# The freq is 1219.909403 Hz.
# The freq is 1219.908947 Hz.
# The freq is 1218.372553 Hz.
# The freq is 1222.111209 Hz.
# The freq is 1219.002545 Hz.
# The freq is 2439.939217 Hz.
# The freq is 2441.510967 Hz.
# The freq is 2439.935033 Hz.
# The freq is 2439.292797 Hz.
# The freq is 2439.737976 Hz.
# The freq is 2439.440034 Hz.
# The freq is 2439.066345 Hz.
# The freq is 2438.936932 Hz.
# The freq is 33.022891 Hz.
# The freq is 1217.979100 Hz.
# The freq is 38.635839 Hz.
# The freq is 2438.065373 Hz.
# The freq is 2438.820902 Hz.
# The freq is 2439.093900 Hz.
# The freq is 2439.632740 Hz.
# The freq is 2439.037238 Hz.
# The freq is 2439.108377 Hz.
# The freq is 2438.663363 Hz.
# The freq is 2437.308859 Hz.
# The freq is 1218.644419 Hz.
# The freq is 38.637505 Hz.
# The freq is 2437.694547 Hz.
# The freq is 2439.255094 Hz.
# The freq is 2438.782285 Hz.
# The freq is 43.565286 Hz.
# The freq is 2438.262075 Hz.
# The freq is 2438.359507 Hz.
# The freq is 2437.970275 Hz.
# The freq is 2438.478935 Hz.
# The freq is 2437.428854 Hz.
# The freq is 2437.274602 Hz.
# The freq is 34.932357 Hz.
# The freq is 14.151418 Hz.
# The freq is 2436.987703 Hz.
# The freq is 116.666858 Hz.
# The freq is 39.595437 Hz.
# The freq is 43.176220 Hz.
# The freq is 41.910077 Hz.
# The freq is 146.468256 Hz.
# The freq is 1218.759610 Hz.
# The freq is 1218.729700 Hz.
# The freq is 1217.729488 Hz.
# The freq is 1218.149305 Hz.
# The freq is 1219.098048 Hz.
# The freq is 1217.611794 Hz.
# The freq is 1218.449674 Hz.
# The freq is 1217.460803 Hz.
# The freq is 1217.446229 Hz.
# The freq is 1218.665291 Hz.
# The freq is 1219.153800 Hz.
# The freq is 1218.241542 Hz.
# The freq is 1218.490241 Hz.
# The freq is 1219.207224 Hz.
# The freq is 1218.338446 Hz.
# The freq is 1219.238566 Hz.
# The freq is 44.914769 Hz.
# The freq is 2438.812305 Hz.
# The freq is 2438.704526 Hz.
# The freq is 2439.283421 Hz.
# The freq is 2439.231920 Hz.
# The freq is 2438.702361 Hz.
# The freq is 2439.478283 Hz.
# The freq is 2439.293881 Hz.
# The freq is 2439.026051 Hz.
# The freq is 2438.810723 Hz.
# The freq is 2438.734542 Hz.
# The freq is 2438.477281 Hz.
# The freq is 2438.561546 Hz.
# The freq is 2438.535572 Hz.
# The freq is 2437.645229 Hz.
# The freq is 2438.265994 Hz.
# The freq is 2437.973666 Hz.
# The freq is 2437.731954 Hz.
# The freq is 1219.198024 Hz.
# The freq is 1219.398635 Hz.
# The freq is 1218.665195 Hz.
# The freq is 1218.744519 Hz.
# The freq is 1218.923938 Hz.
# The freq is 1218.668317 Hz.
# The freq is 1218.292799 Hz.
# The freq is 1218.357363 Hz.
# The freq is 1219.315457 Hz.
# The freq is 1218.957853 Hz.
# The freq is 1218.725944 Hz.
# The freq is 1218.352387 Hz.
# The freq is 1218.803608 Hz.
# The freq is 1217.730042 Hz.
# The freq is 1218.937823 Hz.
# The freq is 1219.651008 Hz.
# The freq is 1217.968540 Hz.
# The freq is 1218.875101 Hz.
# The freq is 46.851598 Hz.
# The freq is 51.354408 Hz.
# The freq is 2438.190465 Hz.
# The freq is 42.458639 Hz.
# The freq is 2436.063139 Hz.
# The freq is 2435.193629 Hz.
# The freq is 2435.946682 Hz.
# The freq is 2436.997627 Hz.
# The freq is 2436.307716 Hz.
# The freq is 2435.134432 Hz.
# The freq is 2434.254442 Hz.
# The freq is 2435.718506 Hz.
# The freq is 2436.341715 Hz.
# The freq is 2436.719397 Hz.
# The freq is 2437.596609 Hz.
# The freq is 2437.294612 Hz.
# The freq is 2437.172462 Hz.
# The freq is 35.544373 Hz.
# The freq is 2436.861376 Hz.
# The freq is 2438.249504 Hz.
# The freq is 2437.183555 Hz.
# The freq is 2438.339044 Hz.
# The freq is 2437.083682 Hz.
# The freq is 36.470602 Hz.
# The freq is 2438.940472 Hz.
# The freq is 2439.340142 Hz.
# The freq is 2439.414379 Hz.
# The freq is 2437.717343 Hz.
# The freq is 2437.847390 Hz.
# The freq is 2438.314297 Hz.
# The freq is 2437.419920 Hz.
# The freq is 2438.062557 Hz.
# The freq is 2438.551798 Hz.
# The freq is 2437.767330 Hz.
# The freq is 2438.207011 Hz.
# The freq is 2437.313406 Hz.
# The freq is 2438.032557 Hz.
# The freq is 2438.329100 Hz.
# The freq is 2438.050120 Hz.
# The freq is 2438.154487 Hz.
# The freq is 2437.745659 Hz.
# The freq is 2437.146856 Hz.
# The freq is 2437.132311 Hz.
# The freq is 2437.949177 Hz.
# The freq is 2437.766062 Hz.
# The freq is 2437.999159 Hz.
# The freq is 2438.859613 Hz.
# The freq is 2438.846306 Hz.
# The freq is 2438.225369 Hz.
# The freq is 35.529752 Hz.
# The freq is 39.722017 Hz.
# The freq is 1220.763785 Hz.
# The freq is 41.779261 Hz.
# The freq is 1219.288038 Hz.
# The freq is 1219.501193 Hz.
# The freq is 1217.026587 Hz.
# The freq is 1219.042705 Hz.
# The freq is 1218.829469 Hz.
# The freq is 1218.287855 Hz.
# The freq is 1219.459461 Hz.
# The freq is 1218.935052 Hz.
# The freq is 1219.133896 Hz.
# The freq is 1219.704061 Hz.
# The freq is 1218.500393 Hz.
# The freq is 1219.182972 Hz.
# The freq is 1222.869564 Hz.
# The freq is 1220.908512 Hz.
# The freq is 46.752393 Hz.
# The freq is 35.572551 Hz.
# The freq is 48.274531 Hz.
# The freq is 40.579255 Hz.
# The freq is 151.572525 Hz.
# The freq is 37.025706 Hz.
# The freq is 20.309601 Hz.
# The freq is 50.424728 Hz.
# The freq is 46.834833 Hz.
# The freq is 40.776269 Hz.
# The freq is 3.922027 Hz.
# The freq is 16.032523 Hz.
# The freq is 1222.000209 Hz.
# The freq is 1219.575455 Hz.
# The freq is 2440.856151 Hz.
# The freq is 2441.242402 Hz.
# The freq is 2440.323762 Hz.
# The freq is 2440.579215 Hz.
# The freq is 2440.226222 Hz.
# The freq is 2439.558708 Hz.
# The freq is 2439.153279 Hz.
# The freq is 2438.723134 Hz.
# The freq is 2439.324602 Hz.
# The freq is 2440.015173 Hz.
# The freq is 2438.772409 Hz.
# The freq is 2438.505384 Hz.
# The freq is 2438.608057 Hz.
# The freq is 45.269999 Hz.
# The freq is 2439.514983 Hz.
# The freq is 1218.581255 Hz.
# The freq is 1218.848744 Hz.
# The freq is 1219.119856 Hz.
# The freq is 1217.998768 Hz.
# The freq is 1217.207402 Hz.
# The freq is 1218.553213 Hz.
# The freq is 1218.825409 Hz.
# The freq is 1217.444116 Hz.
# The freq is 44.175365 Hz.
# The freq is 2436.987692 Hz.
# The freq is 2437.304865 Hz.
# The freq is 2436.902421 Hz.
# The freq is 2436.340958 Hz.
# The freq is 2436.033079 Hz.
# The freq is 46.380996 Hz.
# The freq is 40.085513 Hz.
# The freq is 2437.218472 Hz.
# The freq is 2437.915219 Hz.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-53196f845bf7> in <module>
#      26 while len(data) == chunk*swidth:
#      27     # write data out to the audio stream
# ---> 28     stream.write(data)
#      29     # unpack the data and times by the hamming window
#      30     indata = np.array(wave.struct.unpack("%dh"%(len(data)/swidth),\
#
# ~\Anaconda3\lib\site-packages\pyaudio.py in write(self, frames, num_frames, exception_on_underflow)
#     584
#     585         pa.write_stream(self._stream, frames, num_frames,
# --> 586                         exception_on_underflow)
#     587
#     588
#
# KeyboardInterrupt:
