# %%
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile # get the api
fs, data = wavfile.read(r"C:\Users\turok1997\Desktop\transition\good_failure\device1_channel1_20181021180537.wav") # load the data

# %%
b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
c = fft(b) # calculate fourier transform (complex numbers list)
d = int(len(c)/2)  # you only need half of the fft list (real signal symmetry)
plt.plot(abs(c[:(d-1)]),'r') 
plt.show()

# %%
import os

path = r"C:\Users\turok1997\Desktop\transition\good_failure"

files = os.listdir(path)
for name in files:
    fs, data = wavfile.read(path + "\\" + name ) # load the data
    b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
    c = fft(b) # calculate fourier transform (complex numbers list)
    d = int(len(c)/2)  # you only need half of the fft list (real signal symmetry)
    plt.plot(abs(c[:(d-1)]),'r') 
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-8e491e6230f1> in <module>()
#       6 for name in files:
#       7     fs, data = wavfile.read(path + "\\" + name ) # load the data
# ----> 8     b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
#       9     c = fft(b) # calculate fourier transform (complex numbers list)
#      10     d = int(len(c)/2)  # you only need half of the fft list (real signal symmetry)
#
# <ipython-input-33-8e491e6230f1> in <listcomp>(.0)
#       6 for name in files:
#       7     fs, data = wavfile.read(path + "\\" + name ) # load the data
# ----> 8     b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
#       9     c = fft(b) # calculate fourier transform (complex numbers list)
# ...

# %%
path = r"C:\Users\turok1997\Desktop\transition\failure_good"

files = os.listdir(path)
for name in files:
    fs, data = wavfile.read(path + "\\" + name ) # load the data
    b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
    c = fft(b) # calculate fourier transform (complex numbers list)
    d = int(len(c)/2)  # you only need half of the fft list (real signal symmetry)
    plt.plot(abs(c[:(d-1)]),'r') 
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d9d01cf9c417> in <module>()
#       4 for name in files:
#       5     fs, data = wavfile.read(path + "\\" + name ) # load the data
# ----> 6     b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
#       7     c = fft(b) # calculate fourier transform (complex numbers list)
#       8     d = int(len(c)/2)  # you only need half of the fft list (real signal symmetry)
#
# <ipython-input-34-d9d01cf9c417> in <listcomp>(.0)
#       4 for name in files:
#       5     fs, data = wavfile.read(path + "\\" + name ) # load the data
# ----> 6     b=[(ele/2**8.)*2-1 for ele in data] # this is 8-bit track, b is now normalized on [-1,1)
#       7     c = fft(b) # calculate fourier transform (complex numbers list)
# ...

# %%
rand_fft = np.fft.fft(rand)

# %%
print(rand_fft)
# Out:
# [ 5.66503990e+01+0.j         -1.81087957e+00+0.67414417j
#  -1.95406273e+00+0.72099005j -4.63567191e-01+0.8424645j
#  -1.15695144e+00+0.38146893j -7.13439484e-01+0.14385153j
#   1.53540670e+00-2.87875594j  2.54219800e+00+0.50484456j
#   3.50163491e-01+1.20358965j -4.50341795e+00+2.06691224j
#   1.72290675e+00+1.89175839j -1.19488852e+00+0.65018834j
#   3.00661738e-01-0.69897734j -4.59204357e+00-0.49594989j
#  -2.90901920e+00-0.98361464j  4.58406306e-01+2.85856017j
#  -1.88263635e+00+0.63821728j  3.86893490e+00-0.435717j
#  -3.73434103e+00+2.91936087j -7.69098368e-01+1.6863982j
#   1.90294402e+00-0.32102999j -1.63055252e+00+2.93143799j
#   8.24485731e-01+1.96982511j  1.60563318e+00+0.93830129j
#   1.86044416e+00+3.86441369j -2.33689382e+00-4.27676093j
#  -1.83033631e+00-2.90703075j -4.35297004e-03+2.4795287j
#  -3.29770933e+00+0.39771889j  2.49506555e+00-0.68539934j
#  -5.06032292e-01+1.22417038j  6.80067738e-01+0.26019938j
#  -3.65889221e+00+2.39983018j  2.05750529e+00+2.40084942j
# ...

# %%
plt.plot(rand_fft)
plt.show()
# Out:
# C:\Users\turok1997\Anaconda3\lib\site-packages\numpy\core\numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
